# %%
import pandas as pd

# %%
pd.read_csv("data/pdf_data_to_convert/child_care/table2.txt")
# Out:
#                    State   Infant  Toddler 4-Year-Old Before/After School  \
# 0               Alabama*   $7,670   $7,527     $7,332              $5,090
# 1                 Alaska  $10,809   $9,265     $8,610              $5,559
# 2                Arizona  $10,920  $10,400    $10,400              $5,850
# 3               Arkansas   $7,963   $7,727     $7,745              $4,274
# 4            California*  $19,022       NR    $16,763             $10,293
# 5               Colorado  $13,666  $13,666    $12,830              $8,068
# 6            Connecticut  $14,305      NaN    $13,201              $5,928
# 7               Delaware  $10,997  $10,358     $9,968              $4,294
# 8   District of Columbia  $21,382  $21,022    $19,685                  NR
# 9               Florida*  $11,201  $10,185     $8,592              $5,094
# 10               Georgia   $8,407   $8,043     $7,802              $5,661
# 11                Hawaii  $11,632  $11,148    $11,028             $10,694
# ...

# %%
pd.read_excel("")

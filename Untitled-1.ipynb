# %%
import pandas as pd
import csv
import os

# %%
edu_fod_delete_first_row = {
    "Tab1_FOD.xlsx": True,
    "Tab2_FOD.xlsx": False,
    "Tab3_FOD.xlsx": False,
    "Tab4_FOD.xlsx": False,
    "Tab5_FOD.xlsx": False,
    "Tab6_FOD.xlsx": True,
    "Tab7_FOD.xlsx": True
}

# This dictionary specifies which tables need the first row dropped.

# %%
edu_fod_file_pairs = [
    ("Tab1_FOD.xlsx", "fod_demo_soc.xlsx"),
    ("Tab2_FOD.xlsx", "fod_earn_sex.xlsx"),
    ("Tab3_FOD.xlsx", "fod_earn_age.xlsx"),
    ("Tab4_FOD.xlsx", "fod_earn_race.xlsx"),
    ("Tab5_FOD.xlsx", "fod_earn_edu_att.xlsx"),
    ("Tab6_FOD.xlsx", "fod_metro.xlsx"),
    ("Tab7_FOD.xlsx", "fod_earn_metro.xlsx")
]

# This list of tuples was created to show the input (original) and output (new file) of the data files being renamed.

# %% [markdown]
# This is an exploratory block for testing and will contain lines of code that are commented out.

# %%
def get_column_names(df_header: pd.DataFrame, drop_first_row: bool = False) -> dict[str, str]:
    headers = df_header.head(3)
    
    if drop_first_row:
        headers = headers.drop(0)

    column_names = {}
    last_value = ''
    
    for column in headers:
        first_row_value = headers[column].iloc[0]
        
        if not pd.isna(first_row_value):
            last_value = str(first_row_value).strip()

        second_row_value = headers[column].iloc[1]
        
        if not pd.isna(second_row_value) and second_row_value != "":
            second_row_value = str(second_row_value).strip()
            result = f"{last_value}_{second_row_value}"
            # result = f"{second_row_value}_{last_value}"
        else:
            result = last_value
        
        column_names[column] = result
    
    return column_names

# %% [markdown]
# def Get_column_names(path_to_excel: str, drop_first_row: bool = False) -> dict:
#     headers = pd.read_excel(path_to_excel).head(3)
#
# These two lines of the code block were altered to enable reading and writing to a new (DataFrame) file.

# %%
def rename_all_sheets(all_sheets: dict, drop_first_row: bool = False) -> dict[str, pd.DataFrame]:
    
    renamed_sheets = {}
    
    for sheet_name, df in all_sheets.items():
        names = get_column_names(df, drop_first_row=drop_first_row)

        # getting rid of the old file names
        if drop_first_row:
            df = df.drop([0, 1, 2])
        else:
            df = df.drop([0, 1])
        
        renamed_sheets[sheet_name] = df.rename(columns=names)
        
    return renamed_sheets

# %% [markdown]
# delete_first_row = {
#     1: True,
#     2: False,
#     3: False,
#     4: False,
#     5: False,
#     6: True,
#     7: True
# }
#
# for key, value in delete_first_row.items():
#     filepath = f"data/education/original/Tab{key}_FOD.xlsx"
#     raw = pd.read_excel(filepath)
#     names = get_column_names(filepath, value)
#     raw = raw.rename(columns=names)
#     print(names.values())
#
# This was the original dictionary and code block that read through the original files for analysis purposes before writing. This was altered (removed) to be able to rename all old files, keep changes, and write to new files. The new code is also meant to be universal.

# %%
def write_excel_file(all_sheets: dict[str, pd.DataFrame], output_file: str):
    
    with pd.ExcelWriter(output_file) as writer:
        for sheet_name, df in all_sheets.items():
            df.to_excel(writer, sheet_name=sheet_name, index=False)

# %%
def process_files(file_pairs: list[tuple[str, str]], delete_first_row: dict[str, bool], input_dir: str, output_dir: str):
    
    for input_name, output_name in file_pairs:
        input_file = f"{input_dir}/{input_name}"
        output_file = f"{output_dir}/{output_name}"

        all_sheets = pd.read_excel(input_file, sheet_name=None) # reads all sheets

        renamed_sheets = rename_all_sheets(all_sheets, drop_first_row=[input_name]) # renames all sheets

        return renamed_sheets

        write_excel_file(renamed_sheets, output_file) # writes new file

        print(f"Copied {input_name} / {output_file}")

# %% [markdown]
# The above code block processes a file with the changes applied from previous functions and writes/saves a new file.

# %%
process_files(
    edu_fod_file_pairs,
    edu_fod_delete_first_row,
    input_dir="data/education/original",
    output_dir="data/education/working"
)
# Out:
# {'Table 1':                                       Field of Degree     Total Sex_Male  \
#  3   Population 25 to 64 with a Bachelor's Degree o...  64090000     46.3
#  4                    Science and Engineering Degrees        NaN      NaN
#  5                                   Computer Science    1665000     75.1
#  6                                        Engineering     695400     81.3
#  7                                  Civil Engineering     556200     77.7
#  8                             Electrical Engineering    1197000     84.5
#  9                             Mechanical Engineering    1033000     88.1
#  10                                        Mathematics    699900       57
#  11                                           Biology    2201000     44.2
#  12                                         Chemistry     613000     56.9
#  13                                        Psychology    3075000     26.3
#  14                                         Economics    1267000     64.9
#  15                                 Political Science    1440000     56.8
#  16                                         Sociology     878800     31.4
#  17                                           Nursing    2842000     12.1
#  18             Other Science and Engineering Degrees3  11870000       51
#  19                                  Business Degrees        NaN      NaN
#  20                                  General Business    2844000     57.2
#  21                                        Accounting    2290000     45.3
#  22             Business Management and Adminstration    3839000     51.3
#  23                                         Marketing    1516000     42.8
#  24                                           Finance    1429000     65.5
#  25                            Other Business Degrees    1615000     49.1
#  26                                 Education Degrees        NaN      NaN
#  27                                  General Education   1876000     22.4
#  28                               Elementary Education   1491000      9.6
#  29                            Other Education Degrees   2032000     29.3
#  30                Arts, Humanities and Other Degrees        NaN      NaN
#  31                                    Communications    1658000     38.2
#  32                   English Language and Literature    1670000     33.6
#  33                                      Liberal Arts     744600     38.1
#  34                                           History    1166000     60.8
#  35                                         Fine Arts     684600     38.3
#  36                 Commerical Art and Graphic Design     723300     34.2
#  37                      Family and Consumer Sciences     493300      9.5
#  38   Physical Fitness, Parks, Recreation, and Leisure    855900     54.7
#  39               Criminal Justice and Fire Protection   1385000     58.2
#  40                                       Social Work     637700       13
#  41                                     Other Degrees    5103000     47.2
#  42  Source: U.S. Census Bureau, 2022 American Comm...       NaN      NaN
#  43  The Census Bureau has reviewed this data produ...       NaN      NaN
#  44  Note: 1. See margins of error for these estima...       NaN      NaN
#
#     Sex_Female Age_25 to 34 Age_35 to 44 Age_45 to 54 Age_55 to 64  \
#  3        53.7         28.1         27.8         23.5         20.6
#  4         NaN          NaN          NaN          NaN          NaN
#  5        24.9         30.9         29.5         21.4         18.1
#  6        18.7         24.1         26.1         25.3         24.4
#  7        22.3         29.7         25.8         22.3         22.1
#  8        15.5         22.5         26.3         23.7         27.5
#  9        11.9         33.4         23.7         20.6         22.2
#  10         43         27.2         24.5         22.8         25.4
#  11       55.8         35.6         26.6           22         15.8
#  12       43.1         27.1         24.9         23.3         24.7
#  13       73.7         32.6         28.9         23.3         15.1
#  14       35.1           28         26.1         22.1         23.9
#  15       43.2         26.6         28.1         25.1         20.2
#  16       68.6         26.9         29.5         25.8         17.9
#  17       87.9         28.4         27.1         23.4         21.1
#  18         49         32.3         27.4           22         18.3
#  19        NaN          NaN          NaN          NaN          NaN
#  20       42.8         21.1         27.6         25.2           26
#  21       54.7         22.4         24.6         25.7         27.3
#  22       48.7         20.8           28           25         26.2
#  23       57.2         28.6         28.7         22.5         20.2
#  24       34.5         29.8         28.6         22.4         19.2
#  25       50.9         29.3         29.4         24.3         16.9
#  26        NaN          NaN          NaN          NaN          NaN
#  27       77.6         18.3           27           28         26.8
#  28       90.4         19.1         27.8         26.7         26.4
#  29       70.7         21.9         26.8         24.2         27.2
#  30        NaN          NaN          NaN          NaN          NaN
#  31       61.8         30.1         30.5         23.4           16
#  32       66.4         23.3         28.8         27.3         20.5
#  33       61.9         21.5         29.1         26.2         23.2
#  34       39.2         23.3         29.5         26.6         20.6
#  35       61.7         23.4         29.6         25.4         21.7
#  36       65.8         32.5         32.1         19.8         15.6
#  37       90.5           30         27.9         22.1           20
#  38       45.3         47.9         27.3         17.3          7.5
#  39       41.8         32.1         29.2         24.4         14.3
#  40         87         27.8         27.3         25.2         19.8
#  41       52.8         30.3         29.3         22.2         18.2
#  42        NaN          NaN          NaN          NaN          NaN
#  43        NaN          NaN          NaN          NaN          NaN
#  44        NaN          NaN          NaN          NaN          NaN
#
#     Race and Hispanic Origin2_White Alone  \
#  3                                   65.1
#  4                                    NaN
#  5                                   49.6
#  6                                   53.9
#  7                                   62.1
#  8                                   47.1
#  9                                   64.8
#  10                                  65.4
#  11                                    63
#  12                                  59.6
#  13                                  65.1
#  14                                  62.2
#  15                                  69.1
#  16                                  59.1
#  17                                  63.2
#  18                                  62.2
#  19                                   NaN
#  20                                    67
#  21                                  62.7
#  22                                  62.1
#  23                                  71.7
#  24                                  68.5
#  25                                  60.7
#  26                                   NaN
#  27                                  68.2
#  28                                  79.6
#  29                                  76.5
#  30                                   NaN
#  31                                  70.9
#  32                                  72.8
#  33                                  65.4
#  34                                  77.2
#  35                                  69.4
#  36                                    66
#  37                                  67.7
#  38                                  72.1
#  39                                  61.3
#  40                                  61.4
#  41                                    69
#  42                                   NaN
#  43                                   NaN
#  44                                   NaN
#
#     Race and Hispanic Origin2_Black Alone  ...  \
#  3                                    8.7  ...
#  4                                    NaN  ...
#  5                                    7.8  ...
#  6                                    7.1  ...
#  7                                      5  ...
#  8                                    5.8  ...
#  9                                    3.9  ...
#  10                                   6.8  ...
#  11                                   8.4  ...
#  12                                   7.8  ...
#  13                                  10.6  ...
#  14                                   6.6  ...
#  15                                   8.8  ...
#  16                                  14.9  ...
#  17                                  10.3  ...
#  18                                     8  ...
#  19                                   NaN  ...
#  20                                   9.3  ...
#  21                                   9.2  ...
#  22                                  12.5  ...
#  23                                     8  ...
#  24                                   6.9  ...
#  25                                   9.8  ...
#  26                                   NaN  ...
#  27                                   9.3  ...
#  28                                   5.9  ...
#  29                                   7.2  ...
#  30                                   NaN  ...
#  31                                   9.3  ...
#  32                                   6.2  ...
#  33                                   9.3  ...
#  34                                   5.5  ...
#  35                                   6.1  ...
#  36                                   5.4  ...
#  37                                     9  ...
#  38                                   8.3  ...
#  39                                  15.9  ...
#  40                                  16.9  ...
#  41                                   8.2  ...
#  42                                   NaN  ...
#  43                                   NaN  ...
#  44                                   NaN  ...
#
#     Race and Hispanic Origin2_Other or Multiple Race  \
#  3                                               4.7
#  4                                               NaN
#  5                                               4.7
#  6                                               4.6
#  7                                               4.2
#  8                                                 4
#  9                                               4.3
#  10                                              4.7
#  11                                                5
#  12                                              4.4
#  13                                              5.4
#  14                                              4.5
#  15                                              4.8
#  16                                              5.6
#  17                                              4.3
#  18                                                5
#  19                                              NaN
#  20                                              4.6
#  21                                              3.9
#  22                                              4.6
#  23                                              4.1
#  24                                              4.3
#  25                                              4.7
#  26                                              NaN
#  27                                              4.4
#  28                                              3.8
#  29                                                4
#  30                                              NaN
#  31                                              4.7
#  32                                              4.7
#  33                                                5
#  34                                              4.4
#  35                                              5.2
#  36                                              5.1
#  37                                              4.1
#  38                                                5
#  39                                              4.7
#  40                                              4.4
#  41                                              5.5
#  42                                              NaN
#  43                                              NaN
#  44                                              NaN
#
#     Educational Attainmnent_Bachelor's Degree  \
#  3                                       62.1
#  4                                        NaN
#  5                                       67.4
#  6                                         61
#  7                                       63.9
#  8                                       53.2
#  9                                       61.2
#  10                                      48.5
#  11                                      40.8
#  12                                      37.1
#  13                                      52.4
#  14                                      58.6
#  15                                      47.5
#  16                                      62.9
#  17                                      71.2
#  18                                      56.3
#  19                                       NaN
#  20                                      74.7
#  21                                      68.3
#  22                                      75.2
#  23                                      82.1
#  24                                      69.9
#  25                                      75.4
#  26                                       NaN
#  27                                      50.9
#  28                                      53.5
#  29                                      49.3
#  30                                       NaN
#  31                                        76
#  32                                        53
#  33                                      71.8
#  34                                      49.6
#  35                                      76.9
#  36                                      88.4
#  37                                      68.5
#  38                                      65.4
#  39                                      76.9
#  40                                      47.9
#  41                                      66.1
#  42                                       NaN
#  43                                       NaN
#  44                                       NaN
#
#     Educational Attainmnent_Master's Degree  \
#  3                                     27.6
#  4                                      NaN
#  5                                     28.1
#  6                                     31.3
#  7                                     29.7
#  8                                     37.2
#  9                                     31.8
#  10                                    38.6
#  11                                    23.7
#  12                                    25.2
#  13                                    34.5
#  14                                    29.1
#  15                                    26.4
#  16                                    28.1
#  17                                    20.9
#  18                                    29.1
#  19                                     NaN
#  20                                    21.2
#  21                                    26.5
#  22                                    20.9
#  23                                    15.2
#  24                                    24.9
#  25                                    20.9
#  26                                     NaN
#  27                                    42.9
#  28                                    41.7
#  29                                    43.8
#  30                                     NaN
#  31                                      19
#  32                                    32.7
#  33                                    21.5
#  34                                    31.4
#  35                                    19.6
#  36                                    10.1
#  37                                    26.5
#  38                                    22.6
#  39                                    18.1
#  40                                    47.1
#  41                                    25.1
#  42                                     NaN
#  43                                     NaN
#  44                                     NaN
#
#     Educational Attainmnent_Professional Degree  \
#  3                                            6
#  4                                          NaN
#  5                                          1.6
#  6                                            4
#  7                                          2.6
#  8                                          2.9
#  9                                          2.4
#  10                                         4.8
#  11                                        22.6
#  12                                        15.4
#  13                                         6.3
#  14                                         8.5
#  15                                        21.7
#  16                                         5.5
#  17                                         4.5
#  18                                         7.2
#  19                                         NaN
#  20                                         2.9
#  21                                         4.1
#  22                                         2.7
#  23                                         1.9
#  24                                         4.1
#  25                                         2.6
#  26                                         NaN
#  27                                         3.6
#  28                                           3
#  29                                         3.9
#  30                                         NaN
#  31                                         3.3
#  32                                         8.8
#  33                                         4.5
#  34                                        13.9
#  35                                         2.2
#  36                                         1.1
#  37                                         2.9
#  38                                         5.9
#  39                                         3.6
#  40                                           3
#  41                                         5.2
#  42                                         NaN
#  43                                         NaN
#  44                                         NaN
#
#     Educational Attainmnent_Doctorate Degree Employment_Employed  \
#  3                                       4.4                85.8
#  4                                       NaN                 NaN
#  5                                       2.8                88.2
#  6                                       3.8                87.8
#  7                                       3.8                89.8
#  8                                       6.7                88.5
#  9                                       4.6                90.6
#  10                                      8.1                85.4
#  11                                     12.9                87.2
#  12                                     22.3                86.8
#  13                                      6.8                84.8
#  14                                      3.8                85.5
#  15                                      4.4                87.1
#  16                                      3.5                83.6
#  17                                      3.5                87.5
#  18                                      7.3                86.9
#  19                                      NaN                 NaN
#  20                                      1.2                84.9
#  21                                      1.1                85.7
#  22                                      1.2                86.3
#  23                                      0.9                85.9
#  24                                      1.1                88.4
#  25                                      1.1                87.1
#  26                                      NaN                 NaN
#  27                                      2.6                  81
#  28                                      1.8                80.9
#  29                                        3                82.9
#  30                                      NaN                 NaN
#  31                                      1.7                86.3
#  32                                      5.4                83.4
#  33                                      2.2                81.3
#  34                                        5                86.1
#  35                                      1.3                80.8
#  36                                      0.5                83.2
#  37                                        2                80.3
#  38                                      6.2                88.5
#  39                                      1.4                87.7
#  40                                        2                83.3
#  41                                      3.6                84.8
#  42                                      NaN                 NaN
#  43                                      NaN                 NaN
#  44                                      NaN                 NaN
#
#     Employment_Unemployed Employment_Not in Labor Force  \
#  3                    1.9                          12.3
#  4                    NaN                           NaN
#  5                      2                           9.8
#  6                    1.9                          10.3
#  7                    1.4                           8.8
#  8                    1.7                           9.8
#  9                    1.4                             8
#  10                   1.7                          12.9
#  11                   1.4                          11.3
#  12                   1.6                          11.5
#  13                   2.1                          13.1
#  14                   2.4                          12.1
#  15                     2                          10.9
#  16                   2.3                          14.1
#  17                   1.2                          11.3
#  18                   1.7                          11.4
#  19                   NaN                           NaN
#  20                   1.6                          13.5
#  21                   1.7                          12.5
#  22                     2                          11.7
#  23                     2                          12.1
#  24                   1.9                           9.7
#  25                     2                          10.9
#  26                   NaN                           NaN
#  27                   1.2                          17.8
#  28                   0.8                          18.3
#  29                   1.3                          15.8
#  30                   NaN                           NaN
#  31                   2.4                          11.4
#  32                   2.3                          14.3
#  33                   2.6                          16.1
#  34                   2.2                          11.7
#  35                   2.9                          16.3
#  36                   2.8                            14
#  37                   1.7                            18
#  38                   1.9                           9.6
#  39                     2                          10.3
#  40                   1.6                          15.1
#  41                   2.4                          12.8
#  42                   NaN                           NaN
#  43                   NaN                           NaN
#  44                   NaN                           NaN
#
#     Poverty Status_In Poverty Poverty Status_Not in Poverty
#  3                        4.2                          95.8
#  4                        NaN                           NaN
#  5                        3.5                          96.5
#  6                        4.5                          95.5
#  7                        3.6                          96.4
#  8                        3.5                          96.5
#  9                        3.1                          96.9
#  10                       4.2                          95.8
#  11                       4.4                          95.6
#  12                       3.7                          96.3
#  13                         5                            95
#  14                       4.3                          95.7
#  15                       4.2                          95.8
#  16                       4.6                          95.4
#  17                       3.1                          96.9
#  18                       4.2                          95.8
#  19                       NaN                           NaN
#  20                       4.2                          95.8
#  21                       3.6                          96.4
#  22                       4.2                          95.8
#  23                       3.4                          96.6
#  24                       3.2                          96.8
#  25                       4.1                          95.9
#  26                       NaN                           NaN
#  27                       4.5                          95.5
#  28                       3.1                          96.9
#  29                       3.5                          96.5
#  30                       NaN                           NaN
#  31                       3.9                          96.1
#  32                       4.8                          95.2
#  33                       6.4                          93.6
#  34                       3.9                          96.1
#  35                       7.3                          92.7
#  36                         5                            95
#  37                       4.8                          95.2
#  38                         4                            96
#  39                       4.6                          95.4
#  40                       5.3                          94.7
#  41                       5.4                          94.6
#  42                       NaN                           NaN
#  43                       NaN                           NaN
#  44                       NaN                           NaN
#
#  [42 rows x 22 columns],
#  'Table M1':                                       Field of Degree   Total Sex_Male  \
#  3   Population 25 to 64 with a Bachelor's Degree o...  232300     0.08
#  4                    Science and Engineering Degrees      NaN      NaN
#  5                                   Computer Science    23960     0.59
#  6                                        Engineering    18560     0.99
#  7                                  Civil Engineering    14310     0.96
#  8                             Electrical Engineering    22550      0.6
#  9                             Mechanical Engineering    20030     0.47
#  10                                        Mathematics   15290     0.96
#  11                                           Biology    27830     0.56
#  12                                         Chemistry    13330     1.19
#  13                                        Psychology    36010     0.48
#  14                                         Economics    19010     0.75
#  15                                 Political Science    22890     0.77
#  16                                         Sociology    17350     0.93
#  17                                           Nursing    32200     0.37
#  18             Other Science and Engineering Degrees1   71600     0.23
#  19                                  Business Degrees      NaN      NaN
#  20                                  General Business    33340     0.54
#  21                                        Accounting    27970      0.6
#  22             Business Management and Adminstration    39440     0.45
#  23                                         Marketing    25160     0.63
#  24                                           Finance    20900     0.68
#  25                            Other Business Degrees    26800     0.64
#  26                                 Education Degrees      NaN      NaN
#  27                                  General Education   27440     0.62
#  28                               Elementary Education   22660     0.36
#  29                            Other Education Degrees   28800      0.5
#  30                Arts, Humanities and Other Degrees      NaN      NaN
#  31                                    Communications    24120     0.66
#  32                   English Language and Literature    20970     0.61
#  33                                      Liberal Arts    13350      1.2
#  34                                           History    21500     0.72
#  35                                         Fine Arts    16660     1.11
#  36                 Commerical Art and Graphic Design    17110     1.06
#  37                      Family and Consumer Sciences    11120     0.75
#  38   Physical Fitness, Parks, Recreation, and Leisure   18150     1.21
#  39               Criminal Justice and Fire Protection   24310      0.7
#  40                                       Social Work    14320     0.81
#  41                                     Other Degrees    50010     0.35
#  42  Source: U.S. Census Bureau, 2022 American Comm...     NaN      NaN
#  43  The Census Bureau has reviewed this data produ...     NaN      NaN
#  44  Note: 1. Science and Engineering related field...     NaN      NaN
#
#     Sex_Female Age_25 to 34 Age_35 to 44 Age_45 to 54 Age_55 to 64  \
#  3        0.08         0.09         0.08         0.07         0.07
#  4         NaN          NaN          NaN          NaN          NaN
#  5        0.59         0.67         0.73         0.64         0.47
#  6        0.99         0.96         1.01         0.88         0.92
#  7        0.96         1.07         1.12         0.88         0.94
#  8         0.6         0.68         0.71          0.7         0.62
#  9        0.47         0.82         0.88         0.66         0.83
#  10       0.96         0.96         1.01         0.84         0.96
#  11       0.56         0.54         0.54         0.45         0.41
#  12       1.19         1.04         0.91         1.01         0.97
#  13       0.48         0.44          0.4         0.41         0.36
#  14       0.75         0.78         0.66         0.67          0.7
#  15       0.77         0.66         0.59         0.62         0.58
#  16       0.93         0.94         0.86         0.83         0.67
#  17       0.37         0.52         0.47         0.54          0.4
#  18       0.23         0.28         0.23         0.19         0.19
#  19        NaN          NaN          NaN          NaN          NaN
#  20       0.54         0.49         0.53         0.38         0.48
#  21        0.6          0.6         0.53         0.49         0.53
#  22       0.45         0.43         0.44         0.35         0.36
#  23       0.63         0.69         0.73         0.59         0.64
#  24       0.68         0.72          0.7         0.51         0.53
#  25       0.64         0.63         0.77         0.53         0.46
#  26        NaN          NaN          NaN          NaN          NaN
#  27       0.62         0.49          0.7         0.58         0.59
#  28       0.36         0.55         0.54          0.7         0.62
#  29        0.5         0.49         0.54         0.49         0.47
#  30        NaN          NaN          NaN          NaN          NaN
#  31       0.66         0.65         0.61         0.59         0.46
#  32       0.61         0.58         0.63         0.57         0.59
#  33        1.2         0.84         1.01         1.01         1.02
#  34       0.72         0.77         0.76         0.61          0.6
#  35       1.11         0.92         0.87            1         0.83
#  36       1.06         1.04         1.09         0.93         0.78
#  37       0.75         1.15         1.15         1.04         0.96
#  38       1.21         0.88         0.75         0.63         0.44
#  39        0.7         0.84         0.74         0.62         0.59
#  40       0.81         0.92         1.04         0.96         0.77
#  41       0.35         0.35         0.35         0.27         0.32
#  42        NaN          NaN          NaN          NaN          NaN
#  43        NaN          NaN          NaN          NaN          NaN
#  44        NaN          NaN          NaN          NaN          NaN
#
#     Race and Hispanic Origin_White Alone Race and Hispanic Origin_Black Alone  \
#  3                                   0.1                                 0.07
#  4                                   NaN                                  NaN
#  5                                  0.68                                 0.51
#  6                                  1.13                                 0.72
#  7                                  1.04                                 0.59
#  8                                  0.75                                 0.46
#  9                                  1.06                                 0.39
#  10                                 1.11                                 0.62
#  11                                 0.66                                 0.48
#  12                                 1.07                                 0.74
#  13                                 0.47                                 0.37
#  14                                 0.67                                 0.48
#  15                                 0.84                                 0.57
#  16                                 0.92                                 0.79
#  17                                 0.54                                 0.41
#  18                                 0.25                                 0.17
#  19                                  NaN                                  NaN
#  20                                 0.56                                 0.39
#  21                                 0.52                                  0.4
#  22                                 0.47                                 0.38
#  23                                 0.73                                 0.48
#  24                                 0.65                                 0.55
#  25                                 0.75                                 0.52
#  26                                  NaN                                  NaN
#  27                                 0.65                                 0.44
#  28                                 0.65                                 0.38
#  29                                 0.48                                 0.32
#  30                                  NaN                                  NaN
#  31                                 0.64                                 0.48
#  32                                 0.62                                 0.44
#  33                                 1.04                                 0.63
#  34                                 0.64                                  0.4
#  35                                 1.17                                 0.68
#  36                                 1.12                                 0.58
#  37                                 1.19                                 0.73
#  38                                 0.79                                 0.68
#  39                                  0.8                                 0.67
#  40                                 0.95                                 0.95
#  41                                 0.39                                 0.28
#  42                                  NaN                                  NaN
#  43                                  NaN                                  NaN
#  44                                  NaN                                  NaN
#
#      ... Race and Hispanic Origin_Other or Multiple Race  \
#  3   ...                                            0.05
#  4   ...                                             NaN
#  5   ...                                            0.32
#  6   ...                                            0.43
#  7   ...                                            0.52
#  8   ...                                            0.28
#  9   ...                                            0.41
#  10  ...                                             0.4
#  11  ...                                             0.3
#  12  ...                                            0.47
#  13  ...                                            0.26
#  14  ...                                            0.37
#  15  ...                                            0.34
#  16  ...                                            0.49
#  17  ...                                            0.21
#  18  ...                                             0.1
#  19  ...                                             NaN
#  20  ...                                            0.26
#  21  ...                                            0.23
#  22  ...                                            0.19
#  23  ...                                             0.3
#  24  ...                                            0.31
#  25  ...                                            0.35
#  26  ...                                             NaN
#  27  ...                                            0.28
#  28  ...                                            0.27
#  29  ...                                            0.22
#  30  ...                                             NaN
#  31  ...                                            0.29
#  32  ...                                            0.24
#  33  ...                                            0.45
#  34  ...                                            0.35
#  35  ...                                            0.55
#  36  ...                                             0.5
#  37  ...                                             0.5
#  38  ...                                            0.42
#  39  ...                                            0.32
#  40  ...                                            0.53
#  41  ...                                             0.2
#  42  ...                                             NaN
#  43  ...                                             NaN
#  44  ...                                             NaN
#
#     Educational Attainmnent_Bachelor's Degree  \
#  3                                       0.11
#  4                                        NaN
#  5                                       0.62
#  6                                       1.09
#  7                                       1.15
#  8                                       0.81
#  9                                       0.83
#  10                                      0.98
#  11                                       0.5
#  12                                      1.19
#  13                                      0.45
#  14                                      0.87
#  15                                      0.78
#  16                                      0.84
#  17                                      0.49
#  18                                      0.27
#  19                                       NaN
#  20                                      0.51
#  21                                      0.53
#  22                                      0.39
#  23                                      0.55
#  24                                      0.75
#  25                                      0.74
#  26                                       NaN
#  27                                      0.75
#  28                                      0.59
#  29                                      0.55
#  30                                       NaN
#  31                                      0.58
#  32                                      0.65
#  33                                      0.87
#  34                                      0.89
#  35                                       0.8
#  36                                      0.66
#  37                                      1.08
#  38                                      0.99
#  39                                      0.66
#  40                                      1.14
#  41                                      0.35
#  42                                       NaN
#  43                                       NaN
#  44                                       NaN
#
#     Educational Attainmnent_Master's Degree  \
#  3                                      0.1
#  4                                      NaN
#  5                                     0.64
#  6                                     1.05
#  7                                     1.04
#  8                                     0.82
#  9                                      0.8
#  10                                    0.83
#  11                                    0.59
#  12                                       1
#  13                                    0.41
#  14                                     0.8
#  15                                    0.66
#  16                                    0.84
#  17                                    0.46
#  18                                    0.24
#  19                                     NaN
#  20                                    0.47
#  21                                    0.52
#  22                                    0.37
#  23                                    0.51
#  24                                    0.72
#  25                                    0.65
#  26                                     NaN
#  27                                    0.67
#  28                                    0.61
#  29                                    0.51
#  30                                     NaN
#  31                                    0.55
#  32                                    0.64
#  33                                    0.81
#  34                                    0.82
#  35                                    0.76
#  36                                    0.61
#  37                                    1.07
#  38                                    0.82
#  39                                    0.66
#  40                                    1.18
#  41                                    0.27
#  42                                     NaN
#  43                                     NaN
#  44                                     NaN
#
#     Educational Attainmnent_Professional Degree  \
#  3                                         0.06
#  4                                          NaN
#  5                                          0.2
#  6                                         0.41
#  7                                         0.38
#  8                                          0.3
#  9                                         0.26
#  10                                        0.39
#  11                                        0.51
#  12                                        0.79
#  13                                        0.24
#  14                                         0.4
#  15                                        0.66
#  16                                        0.41
#  17                                        0.21
#  18                                        0.13
#  19                                         NaN
#  20                                        0.17
#  21                                        0.26
#  22                                        0.16
#  23                                         0.2
#  24                                        0.31
#  25                                        0.25
#  26                                         NaN
#  27                                        0.26
#  28                                        0.25
#  29                                         0.2
#  30                                         NaN
#  31                                        0.21
#  32                                        0.41
#  33                                        0.38
#  34                                        0.55
#  35                                        0.33
#  36                                        0.22
#  37                                        0.39
#  38                                        0.46
#  39                                         0.3
#  40                                        0.36
#  41                                         0.2
#  42                                         NaN
#  43                                         NaN
#  44                                         NaN
#
#     Educational Attainmnent_Doctorate Degree Employment_Employed  \
#  3                                      0.04                0.07
#  4                                       NaN                 NaN
#  5                                      0.26                0.44
#  6                                      0.43                0.73
#  7                                      0.46                0.73
#  8                                      0.36                0.57
#  9                                       0.4                0.52
#  10                                      0.5                0.71
#  11                                     0.41                0.41
#  12                                     0.82                0.73
#  13                                     0.28                0.36
#  14                                     0.28                0.65
#  15                                     0.25                 0.4
#  16                                     0.32                0.62
#  17                                     0.18                0.36
#  18                                     0.13                0.16
#  19                                      NaN                 NaN
#  20                                     0.12                0.36
#  21                                     0.14                0.39
#  22                                      0.1                0.29
#  23                                     0.14                0.53
#  24                                     0.16                0.47
#  25                                     0.15                0.45
#  26                                      NaN                 NaN
#  27                                     0.19                0.55
#  28                                      0.2                0.43
#  29                                     0.18                 0.4
#  30                                      NaN                 NaN
#  31                                     0.15                0.49
#  32                                      0.3                0.55
#  33                                     0.31                0.95
#  34                                     0.32                0.51
#  35                                     0.24                0.93
#  36                                     0.12                0.91
#  37                                      0.3                0.88
#  38                                     0.42                0.67
#  39                                     0.21                0.54
#  40                                      0.3                0.97
#  41                                     0.15                 0.3
#  42                                      NaN                 NaN
#  43                                      NaN                 NaN
#  44                                      NaN                 NaN
#
#     Employment_Unemployed Employment_Not in Labor Force  \
#  3                   0.03                          0.07
#  4                    NaN                           NaN
#  5                   0.17                          0.45
#  6                    0.3                          0.62
#  7                   0.32                          0.63
#  8                   0.24                          0.49
#  9                   0.18                          0.51
#  10                  0.28                          0.66
#  11                  0.15                           0.4
#  12                  0.34                          0.67
#  13                  0.13                          0.33
#  14                  0.27                          0.53
#  15                  0.26                          0.39
#  16                  0.24                          0.63
#  17                  0.13                          0.35
#  18                  0.05                          0.16
#  19                   NaN                           NaN
#  20                  0.13                          0.34
#  21                  0.16                          0.36
#  22                  0.14                          0.28
#  23                  0.21                          0.48
#  24                  0.22                          0.43
#  25                   0.2                          0.41
#  26                   NaN                           NaN
#  27                  0.16                          0.53
#  28                  0.13                          0.42
#  29                  0.14                          0.38
#  30                   NaN                           NaN
#  31                  0.21                          0.47
#  32                  0.21                          0.48
#  33                  0.48                          0.79
#  34                  0.27                          0.45
#  35                  0.35                          0.87
#  36                  0.33                          0.83
#  37                   0.3                          0.84
#  38                  0.22                          0.63
#  39                  0.22                          0.47
#  40                  0.29                          0.97
#  41                  0.11                          0.27
#  42                   NaN                           NaN
#  43                   NaN                           NaN
#  44                   NaN                           NaN
#
#     Poverty Status_In Poverty Poverty Status_Not In Poverty
#  3                       0.05                          0.05
#  4                        NaN                           NaN
#  5                       0.32                          0.32
#  6                       0.47                          0.47
#  7                       0.56                          0.56
#  8                       0.36                          0.36
#  9                       0.31                          0.31
#  10                      0.44                          0.44
#  11                      0.28                          0.28
#  12                      0.45                          0.45
#  13                      0.24                          0.24
#  14                      0.32                          0.32
#  15                      0.33                          0.33
#  16                      0.46                          0.46
#  17                      0.19                          0.19
#  18                      0.13                          0.13
#  19                       NaN                           NaN
#  20                      0.22                          0.22
#  21                      0.26                          0.26
#  22                      0.18                          0.18
#  23                      0.23                          0.23
#  24                      0.28                          0.28
#  25                       0.3                           0.3
#  26                       NaN                           NaN
#  27                      0.31                          0.31
#  28                      0.26                          0.26
#  29                      0.25                          0.25
#  30                       NaN                           NaN
#  31                      0.28                          0.28
#  32                      0.33                          0.33
#  33                      0.46                          0.46
#  34                      0.34                          0.34
#  35                       0.6                           0.6
#  36                      0.47                          0.47
#  37                      0.61                          0.61
#  38                      0.32                          0.32
#  39                      0.38                          0.38
#  40                      0.53                          0.53
#  41                      0.19                          0.19
#  42                       NaN                           NaN
#  43                       NaN                           NaN
#  44                       NaN                           NaN
#
#  [42 rows x 22 columns]}

# %%
def strip_object_columns(df: pd.DataFrame) -> pd.DataFrame:

    for column in df.select_dtypes(include=['object']).columns:
        df[column] = df[column].astype(str).str.strip()
    
    return df

# %% [markdown]
# This function strips all numeric columns to remove extra spacing and formatting.

# %%
def clean_numeric_columns(df: pd.DataFrame, threshold: float = 0.7) -> pd.DataFrame: # adds a threshold of 0.7 (70%); so unless the row has 70% >= non-null values that are numeric, it will execute, if not, no conversion will be done on that row 
    df = df.copy()
    
    for col in df.columns:
        if col.lower() in {"field_of_degree"}:
            continue
        
        cleaned = (
            df[col]
            .astype(str)
            .str.replace(",", "", regex=False)
            .str.replace("$", "", regex=False)
            .str.replace("%", "", regex=False)
        )

        numeric = pd.to_numeric(cleaned, errors="coerce") # updated "ignore" to "coerce" due to FutureWarning

        non_null = cleaned.notna().sum()
        numeric_count = numeric.notna().sum()

        if non_null > 0 and numeric_count / non_null >= threshold: 
            df[col] = numeric
    
    return df

# %% [markdown]
# This function will remove ",", "$", and "%" from any column that is an object (str) and converts them to numbers (int64, float64). If it is a column with text only (or an error occurs), the column will not be altered.

# %%
def remove_empty_rows(df: pd.DataFrame) -> pd.DataFrame: # this will remove the rows where the numeric columns are NaN
    numeric_cols = df.select_dtypes(include=['number']).columns
    
    if len(numeric_cols) == 0:
        return df # this checks the number of numeric rows; if 0, then it will end
    
    return df.dropna(subset=numeric_cols, how='all')

# %%
def format_numbers(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    
    def format_whole_numbers(x):
        if pd.isna(x):
            return x
        if isinstance(x, float) and x.is_integer():
            return int(x)
        return x

    numeric_cols = df.select_dtypes(include=['number']).columns
    df[numeric_cols] = df[numeric_cols].applymap(format_whole_numbers)

    return df

# function that formats numbers with no decimal value to whole integers and leaves float values untouched

# %% [markdown]
# # markdown

# %%
# def clean_csv_for_calc(file_path: str) -> pd.DataFrame:
#     df = pd.read_csv(file_path)
#     df = strip_object_columns(df)
#     df = clean_numeric_columns(df)
#     df = remove_empty_rows(df)
#     df = format_numbers(df)
    
#     return df

# file_path = "data/education/cleaned/fod_demo_soc_table_1.csv"
# df_clean = clean_csv_for_calc(file_path)

# print(df_clean.info())
# print(df_clean.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 22 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Field of Degree                                   42 non-null     object
#  1   Total                                             35 non-null     float64
#  2   Sex.Male                                          35 non-null     float64
#  3   Sex.Female                                        35 non-null     float64
#  4   Age.25 to 34                                      35 non-null     float64
#  5   Age.35 to 44                                      35 non-null     float64
#  6   Age.45 to 54                                      35 non-null     float64
#  7   Age.55 to 64                                      35 non-null     float64
#  8   Race and Hispanic Origin2.White Alone             35 non-null     float64
#  9   Race and Hispanic Origin2.Black Alone             35 non-null     float64
#  10  Race and Hispanic Origin2.Asian Alone             35 non-null     float64
#  11  Race and Hispanic Origin2.Hispanic, of Any Race   35 non-null     float64
#  12  Race and Hispanic Origin2.Other or Multiple Race  35 non-null     float64
#  13  Educational Attainmnent.Bachelor's Degree         35 non-null     float64
#  14  Educational Attainmnent.Master's Degree           35 non-null     float64
#  15  Educational Attainmnent.Professional Degree       35 non-null     float64
#  16  Educational Attainmnent.Doctorate Degree          35 non-null     float64
#  17  Employment.Employed                               35 non-null     float64
#  18  Employment.Unemployed                             35 non-null     float64
#  19  Employment.Not in Labor Force                     35 non-null     float64
#  20  Poverty Status.In Poverty                         35 non-null     float64
#  21  Poverty Status.Not in Poverty                     35 non-null     float64
# dtypes: float64(21), object(1)
# memory usage: 7.3+ KB
# None
#                                      Field of Degree       Total  Sex.Male  \
# 0  Population 25 to 64 with a Bachelor's Degree o...  64090000.0      46.3
# 1                    Science and Engineering Degrees         NaN       NaN
# 2                                   Computer Science   1665000.0      75.1
# 3                                        Engineering    695400.0      81.3
# 4                                  Civil Engineering    556200.0      77.7
#
#    Sex.Female  Age.25 to 34  Age.35 to 44  Age.45 to 54  Age.55 to 64  \
# 0        53.7          28.1          27.8          23.5          20.6
# 1         NaN           NaN           NaN           NaN           NaN
# 2        24.9          30.9          29.5          21.4          18.1
# 3        18.7          24.1          26.1          25.3          24.4
# 4        22.3          29.7          25.8          22.3          22.1
#
#    Race and Hispanic Origin2.White Alone  \
# 0                                   65.1
# 1                                    NaN
# 2                                   49.6
# 3                                   53.9
# 4                                   62.1
#
#    Race and Hispanic Origin2.Black Alone  ...  \
# 0                                    8.7  ...
# 1                                    NaN  ...
# 2                                    7.8  ...
# 3                                    7.1  ...
# 4                                    5.0  ...
#
#    Race and Hispanic Origin2.Other or Multiple Race  \
# 0                                               4.7
# 1                                               NaN
# 2                                               4.7
# 3                                               4.6
# 4                                               4.2
#
#    Educational Attainmnent.Bachelor's Degree  \
# 0                                       62.1
# 1                                        NaN
# 2                                       67.4
# 3                                       61.0
# 4                                       63.9
#
#    Educational Attainmnent.Master's Degree  \
# 0                                     27.6
# 1                                      NaN
# 2                                     28.1
# 3                                     31.3
# 4                                     29.7
#
#    Educational Attainmnent.Professional Degree  \
# 0                                          6.0
# 1                                          NaN
# 2                                          1.6
# 3                                          4.0
# 4                                          2.6
#
#    Educational Attainmnent.Doctorate Degree  Employment.Employed  \
# 0                                       4.4                 85.8
# 1                                       NaN                  NaN
# 2                                       2.8                 88.2
# 3                                       3.8                 87.8
# 4                                       3.8                 89.8
#
#    Employment.Unemployed  Employment.Not in Labor Force  \
# 0                    1.9                           12.3
# 1                    NaN                            NaN
# 2                    2.0                            9.8
# 3                    1.9                           10.3
# 4                    1.4                            8.8
#
#    Poverty Status.In Poverty  Poverty Status.Not in Poverty
# 0                        4.2                           95.8
# 1                        NaN                            NaN
# 2                        3.5                           96.5
# 3                        4.5                           95.5
# 4                        3.6                           96.4
#
# [5 rows x 22 columns]

# %% [markdown]
# # markdown

# %%
def clean_test(df: pd.DataFrame, use_dot_hierarchy: bool = True) -> pd.DataFrame:
    df = df.copy()

    if use_dot_hierarchy:
        df.columns =df.columns.str.replace("_", ".", regex=False)

    df = strip_object_columns(df)
    df = clean_numeric_columns(df)
    df = df.dropna(how='all')

    return df

# %% [markdown]
# # markdown

# %%
def excel_to_csv_batch(
        input_dir: str,
        output_dir: str,
        filenames: list[str],
        use_dot_hierarchy: bool = True # preferred method of header hierarchy # can toggle True/False
):

    for filename in filenames:
        input_file = f"{input_dir}/{filename}"
        orig_name = filename.replace(".xlsx", "")

        all_sheets = pd.read_excel(input_file, sheet_name=None)

        for sheet_name, df in all_sheets.items():
            safe_sheet_name = sheet_name.replace(" ", "_").lower()
            
            if use_dot_hierarchy:
                df.columns = df.columns.str.replace("_", ".", regex=False) # replacing "_" with "." for header hierarchy
            
            df = strip_object_columns(df)

            df = clean_numeric_columns(df)

            df = remove_empty_rows(df)

            df = format_numbers(df)
            
            output_file = f"{output_dir}/{orig_name}_{safe_sheet_name}.csv"

            df.to_csv(output_file, index=False)
            print(f"Saved: {output_file}")

# %%
edu_files = [
    "fod_demo_soc.xlsx",
    "fod_earn_age.xlsx",
    "fod_earn_edu_att.xlsx",
    "fod_earn_metro.xlsx",
    "fod_earn_race.xlsx",
    "fod_earn_sex.xlsx",
    "fod_metro.xlsx"
]

excel_to_csv_batch(
    input_dir="data/education/working",
    output_dir="data/education/cleaned",
    filenames=edu_files
)
# Out:
# Saved: data/education/cleaned/fod_demo_soc_table_1.csv
# Saved: data/education/cleaned/fod_demo_soc_table_m1.csv
# Saved: data/education/cleaned/fod_earn_age_table_3.csv
# Saved: data/education/cleaned/fod_earn_edu_att_table_5-attainment_earnings.csv
# Saved: data/education/cleaned/fod_earn_metro_table_7.csv
# Saved: data/education/cleaned/fod_earn_metro_table_m3.csv
# Saved: data/education/cleaned/fod_earn_race_table_4-race_earnings.csv
# Saved: data/education/cleaned/fod_earn_sex_table_2.csv
# Saved: data/education/cleaned/fod_metro_table_6.csv
# Saved: data/education/cleaned/fod_metro_table_m2.csv
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_6336\3887946779.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[numeric_cols] = df[numeric_cols].applymap(format_whole_numbers)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_6336\3887946779.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[numeric_cols] = df[numeric_cols].applymap(format_whole_numbers)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_6336\3887946779.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[numeric_cols] = df[numeric_cols].applymap(format_whole_numbers)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_6336\3887946779.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[numeric_cols] = df[numeric_cols].applymap(format_whole_numbers)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_6336\3887946779.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[numeric_cols] = df[numeric_cols].applymap(format_whole_numbers)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_6336\3887946779.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[numeric_cols] = df[numeric_cols].applymap(format_whole_numbers)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_6336\3887946779.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[numeric_cols] = df[numeric_cols].applymap(format_whole_numbers)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_6336\3887946779.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[numeric_cols] = df[numeric_cols].applymap(format_whole_numbers)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_6336\3887946779.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[numeric_cols] = df[numeric_cols].applymap(format_whole_numbers)
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_6336\3887946779.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[numeric_cols] = df[numeric_cols].applymap(format_whole_numbers)

# %% [markdown]
# # markdown

# %%
FORMAT_MAP = {}

# %%
df = pd.read_csv("data/education/cleaned/fod_demo_soc_table_1.csv")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 22 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Field of Degree                                   42 non-null     object
#  1   Total                                             35 non-null     float64
#  2   Sex.Male                                          35 non-null     float64
#  3   Sex.Female                                        35 non-null     float64
#  4   Age.25 to 34                                      35 non-null     float64
#  5   Age.35 to 44                                      35 non-null     float64
#  6   Age.45 to 54                                      35 non-null     float64
#  7   Age.55 to 64                                      35 non-null     float64
#  8   Race and Hispanic Origin2.White Alone             35 non-null     float64
#  9   Race and Hispanic Origin2.Black Alone             35 non-null     float64
#  10  Race and Hispanic Origin2.Asian Alone             35 non-null     float64
#  11  Race and Hispanic Origin2.Hispanic, of Any Race   35 non-null     float64
#  12  Race and Hispanic Origin2.Other or Multiple Race  35 non-null     float64
#  13  Educational Attainmnent.Bachelor's Degree         35 non-null     float64
#  14  Educational Attainmnent.Master's Degree           35 non-null     float64
#  15  Educational Attainmnent.Professional Degree       35 non-null     float64
#  16  Educational Attainmnent.Doctorate Degree          35 non-null     float64
#  17  Employment.Employed                               35 non-null     float64
#  18  Employment.Unemployed                             35 non-null     float64
#  19  Employment.Not in Labor Force                     35 non-null     float64
#  20  Poverty Status.In Poverty                         35 non-null     float64
#  21  Poverty Status.Not in Poverty                     35 non-null     float64
# dtypes: float64(21), object(1)
# memory usage: 7.3+ KB

# %%
copy_csv = False # flag variable used to keep from constant overwriting when using "Run All" # can be changed to 'True' for execution.

input_file = "data/child_care/original/Map by price and county_Full Data_data.csv"
output_file = "data/child_care/cleaned/child_care_full_map.csv"

if copy_csv:
    df_childcare_map = pd.read_csv(input_file, dtype={"County Fips Code": str}) # have to convert to str for pandas to read FIPS that start with 0 correctly
    
    df_childcare_map = pd.rename(columns={
        "Flfpr 20To64: Women's Labor Force Participation Rate (Percentage)",
        "Fme 2022: Women's Median Earnings",
        "Hispanic: Hispanic (Percentage)",
        


    }, inplace=True)
    
    df_childcare_map["County Fips Code"] = df_childcare_map["County Fips Code"].str.zfill(5)
    
    df_childcare_map.to_csv(output_file, index=False)

# df_childcare_map = pd.read_csv(output_file, dtype={"County Fips Code": str}) # have to specify dtype when reading, or will show incorrect FIPS starting with 0
# print(df_childcare_map.head())
# print(df_childcare_map.columns)
# df_childcare_map.info()

# %% [markdown]
# # markdown

# %%
df = pd.read_excel("data/education/working/fod_metro.xlsx", sheet_name=0)

# print("Before CLeaning:")
# print(df.shape)
# display(df.head(50))

print(df.dtypes)
# Out:
# Select Metropolitan Statistical Areas                                                   object
# Total Population                                                                       float64
# Educational Attainment_Less than a Bachelor's Degree                                   float64
# Educational Attainment_All Bachelor's Degree Holders                                   float64
# Science and Engineering Degrees_Computer Science                                       float64
# Science and Engineering Degrees_Engineering                                            float64
# Science and Engineering Degrees_Civil Engineering                                      float64
# Science and Engineering Degrees_Electrical Engineering                                 float64
# Science and Engineering Degrees_Mechanical Engineering                                 float64
# Science and Engineering Degrees_Mathematics                                            float64
# Science and Engineering Degrees_Biology                                                float64
# Science and Engineering Degrees_Chemistry                                              float64
# Science and Engineering Degrees_Psychology                                             float64
# Science and Engineering Degrees_Economics                                              float64
# Science and Engineering Degrees_Political Science                                      float64
# Science and Engineering Degrees_Sociology                                              float64
# Science and Engineering Degrees_Nursing                                                float64
# Science and Engineering Degrees_Other Science and Engineering Degrees2                 float64
# Business Degrees_General Business                                                      float64
# Business Degrees_Accounting                                                            float64
# Business Degrees_Business Management and Adminstration                                 float64
# Business Degrees_Marketing                                                             float64
# Business Degrees_Finance                                                               float64
# Business Degrees_Other Business Degrees                                                float64
# Education Degrees_General Education                                                    float64
# Education Degrees_Elementary Education                                                 float64
# Education Degrees_Other Education Degrees                                              float64
# Arts, Humanities and Other Degrees_Communications                                      float64
# Arts, Humanities and Other Degrees_English Language and Literature                     float64
# Arts, Humanities and Other Degrees_Liberal Arts                                        float64
# Arts, Humanities and Other Degrees_History                                             float64
# Arts, Humanities and Other Degrees_Fine Arts                                           float64
# Arts, Humanities and Other Degrees_Commerical Art and Graphic Design                   float64
# Arts, Humanities and Other Degrees_Family and Consumer Sciences                        float64
# Arts, Humanities and Other Degrees_Physical Fitness, Parks, Recreation, and Leisure    float64
# Arts, Humanities and Other Degrees_Criminal Justice and Fire Protection                float64
# Arts, Humanities and Other Degrees_Social Work                                         float64
# Arts, Humanities and Other Degrees_Other Degrees                                       float64
# dtype: object

# %%
df1 = strip_object_columns(df)
print(df1.dtypes)
# Out:
# _Select Metropolitan Statistical Areas                                                  object
# Educational Attainment_Less than a Bachelor's Degree                                   float64
# Educational Attainment_Bachelor's Degree or Higher                                     float64
# Science and Engineering Degrees_Computer Science                                       float64
# Science and Engineering Degrees_Engineering                                            float64
# Science and Engineering Degrees_Civil Engineering                                      float64
# Science and Engineering Degrees_Electrical Engineering                                 float64
# Science and Engineering Degrees_Mechanical Engineering                                 float64
# Science and Engineering Degrees_Mathematics                                            float64
# Science and Engineering Degrees_Biology                                                float64
# Science and Engineering Degrees_Chemistry                                              float64
# Science and Engineering Degrees_Psychology                                             float64
# Science and Engineering Degrees_Economics                                              float64
# Science and Engineering Degrees_Political Science                                      float64
# Science and Engineering Degrees_Sociology                                              float64
# Science and Engineering Degrees_Nursing                                                float64
# Science and Engineering Degrees_Other Science and Engineering Degrees2                 float64
# Business Degrees_General Business                                                      float64
# Business Degrees_Accounting                                                            float64
# Business Degrees_Business Management and Adminstration                                 float64
# Business Degrees_Marketing                                                             float64
# Business Degrees_Finance                                                               float64
# Business Degrees_Other Business Degrees                                                float64
# Education Degrees_General Education                                                    float64
# Education Degrees_Elementary Education                                                 float64
# Education Degrees_Other Education Degrees                                              float64
# Arts, Humanities and Other Degrees_Communications                                      float64
# Arts, Humanities and Other Degrees_English Language and Literature                     float64
# Arts, Humanities and Other Degrees_Liberal Arts                                        float64
# Arts, Humanities and Other Degrees_History                                             float64
# Arts, Humanities and Other Degrees_Fine Arts                                           float64
# Arts, Humanities and Other Degrees_Commerical Art and Graphic Design                   float64
# Arts, Humanities and Other Degrees_Family and Consumer Sciences                        float64
# Arts, Humanities and Other Degrees_Physical Fitness, Parks, Recreation, and Leisure    float64
# Arts, Humanities and Other Degrees_Criminal Justice and Fire Protection                float64
# Arts, Humanities and Other Degrees_Social Work                                         float64
# Arts, Humanities and Other Degrees_Other Degrees                                       float64
# dtype: object

# %%
df2 = clean_numeric_columns(df1)
print(df2.dtypes)
# Out:
# Field of Degree                                     float64
# Total                                               float64
# Sex_Male                                            float64
# Sex_Female                                          float64
# Age_25 to 34                                        float64
# Age_35 to 44                                        float64
# Age_45 to 54                                        float64
# Age_55 to 64                                        float64
# Race and Hispanic Origin2_White Alone               float64
# Race and Hispanic Origin2_Black Alone               float64
# Race and Hispanic Origin2_Asian Alone               float64
# Race and Hispanic Origin2_Hispanic, of Any Race     float64
# Race and Hispanic Origin2_Other or Multiple Race    float64
# Educational Attainmnent_Bachelor's Degree           float64
# Educational Attainmnent_Master's Degree             float64
# Educational Attainmnent_Professional Degree         float64
# Educational Attainmnent_Doctorate Degree            float64
# Employment_Employed                                 float64
# Employment_Unemployed                               float64
# Employment_Not in Labor Force                       float64
# Poverty Status_In Poverty                           float64
# Poverty Status_Not in Poverty                       float64
# dtype: object

# %%
# numeric_cols = df2.select_dtypes(include="number").columns
# print("Numeric columns:", list(numeric_cols))
# print("Row count:", len(df2))

# %%
df_test = df.copy()

df_test = strip_object_columns(df_test)
df_test = clean_numeric_columns(df_test)
df_test = remove_empty_rows(df_test)
df_test.columns = df_test.columns.str.replace("_", ".", regex=False)

print("After cleaning:")
print(df_test.shape)
display(df_test.head(50))
# Out:
# After cleaning:
# (35, 9)
#                                       Field of Degree  \
# 0   Population 25 to 64 with a Bachelor's Degree o...
# 2                                    Computer Science
# 3                                         Engineering
# 4                                   Civil Engineering
# 5                              Electrical Engineering
# 6                              Mechanical Engineering
# 7                                         Mathematics
# 8                                             Biology
# 9                                           Chemistry
# 10                                         Psychology
# 11                                          Economics
# 12                                  Political Science
# 13                                          Sociology
# 14                                            Nursing
# 15             Other Science and Engineering Degrees1
# 17                                   General Business
# 18                                         Accounting
# 19              Business Management and Adminstration
# 20                                          Marketing
# 21                                            Finance
# 22                             Other Business Degrees
# 24                                  General Education
# 25                               Elementary Education
# 26                            Other Education Degrees
# 28                                     Communications
# 29                    English Language and Literature
# 30                                       Liberal Arts
# 31                                            History
# 32                                          Fine Arts
# 33                  Commerical Art and Graphic Design
# 34                       Family and Consumer Sciences
# 35   Physical Fitness, Parks, Recreation, and Leisure
# 36               Criminal Justice and Fire Protection
# 37                                        Social Work
# 38                                      Other Degrees
#
#     Total Population.Estimate  Total Population.MOE  Men.Estimate  Men.MOE  \
# 0                     74150.0                 165.7       89300.0    358.2
# 2                    108500.0                1597.0      115500.0   1749.0
# 3                    100600.0                1031.0      103300.0   1409.0
# 4                     99660.0                1702.0      101900.0   1048.0
# 5                    121600.0                1239.0      123800.0   1203.0
# 6                    106200.0                 957.2      108000.0   1584.0
# 7                     86560.0                1476.0       99050.0   3109.0
# 8                     81550.0                 706.8       96620.0   2112.0
# 9                     94680.0                2114.0      103000.0   1802.0
# 10                    62270.0                 488.2       76090.0   1168.0
# 11                   101400.0                 916.1      107300.0   1277.0
# 12                    86380.0                1325.0       94950.0   2075.0
# 13                    63660.0                 836.9       75030.0   3295.0
# 14                    79600.0                 812.7       90890.0   1569.0
# 15                    77910.0                 460.3       92050.0    425.4
# 17                    80120.0                 710.7       90080.0   1351.0
# 18                    84880.0                1051.0      100000.0   1751.0
# 19                    75600.0                 581.2       87090.0    949.5
# 20                    75930.0                 798.6       89420.0   2472.0
# 21                    99900.0                1779.0      106400.0   1202.0
# 22                    77160.0                 882.2       91000.0   1361.0
# 24                    58000.0                 730.8       68420.0   2078.0
# 25                    54900.0                 549.8       64380.0   2283.0
# 26                    58120.0                 477.6       66560.0    897.1
# 28                    67840.0                1017.0       75400.0   1336.0
# 29                    65060.0                 927.0       75850.0   1488.0
# 30                    61380.0                1044.0       70850.0   3288.0
# 31                    73560.0                1006.0       81270.0   1116.0
# 32                    53450.0                1303.0       60900.0   1630.0
# 33                    59770.0                1049.0       69930.0   1932.0
# 34                    52850.0                 951.6       70440.0   6831.0
# 35                    61580.0                 691.3       65120.0   1259.0
# 36                    64690.0                 809.2       74250.0   1150.0
# 37                    55060.0                 838.0       60090.0   2905.0
# 38                    62100.0                 419.6       69830.0    903.6
#
#     Women.Estimate  Women.MOE  \
# 0          63230.0      131.9
# 2          91990.0     2082.0
# 3          76160.0     6168.0
# 4          86590.0     3583.0
# 5         105200.0     2719.0
# 6          92380.0     3243.0
# 7          73500.0     1814.0
# 8          72200.0      961.4
# 9          80180.0     3164.0
# 10         58490.0      805.7
# 11         84750.0     2198.0
# 12         77090.0     1463.0
# 13         59470.0     1082.0
# 14         77640.0      783.9
# 15         65150.0      429.9
# 17         66690.0     1431.0
# 18         75010.0     1155.0
# 19         63640.0      588.1
# 20         66090.0     1402.0
# 21         79940.0     1713.0
# 22         64900.0     1218.0
# 24         55030.0      567.6
# 25         54070.0      543.6
# 26         54600.0      481.2
# 28         64130.0      780.4
# 29         61150.0      820.0
# 30         55790.0     1988.0
# 31         62980.0     1455.0
# 32         49530.0     1767.0
# 33         54350.0     1047.0
# 34         51590.0     1157.0
# 35         55600.0     1458.0
# 36         54150.0      829.9
# 37         54380.0      742.7
# 38         55740.0      638.6
#
#     Women's Earnings as a Percentage of Men's Earnings.Estimate  \
# 0                                                70.8
# 2                                                79.6
# 3                                                73.7
# 4                                                85.0
# 5                                                85.0
# 6                                                85.5
# 7                                                74.2
# 8                                                74.7
# 9                                                77.8
# 10                                               76.9
# 11                                               79.0
# 12                                               81.2
# 13                                               79.3
# 14                                               85.4
# 15                                               70.8
# 17                                               74.0
# 18                                               75.0
# 19                                               73.1
# 20                                               73.9
# 21                                               75.1
# 22                                               71.3
# 24                                               80.4
# 25                                               84.0
# 26                                               82.0
# 28                                               85.1
# 29                                               80.6
# 30                                               78.7
# 31                                               77.5
# 32                                               81.3
# 33                                               77.7
# 34                                               73.2
# 35                                               85.4
# 36                                               72.9
# 37                                               90.5
# 38                                               79.8
#
#     Women's Earnings as a Percentage of Men's Earnings.MOE
# 0                                                 0.3
# 2                                                 2.2
# 3                                                 6.1
# 4                                                 3.6
# 5                                                 2.3
# 6                                                 3.3
# 7                                                 3.0
# 8                                                 1.9
# 9                                                 3.4
# 10                                                1.6
# 11                                                2.3
# 12                                                2.3
# 13                                                3.8
# 14                                                1.7
# 15                                                0.6
# 17                                                1.9
# 18                                                1.7
# 19                                                1.0
# 20                                                2.6
# 21                                                1.8
# 22                                                1.7
# 24                                                2.6
# 25                                                3.1
# 26                                                1.3
# 28                                                1.8
# 29                                                1.9
# 30                                                4.6
# 31                                                2.1
# 32                                                3.6
# 33                                                2.6
# 34                                                7.3
# 35                                                2.8
# 36                                                1.6
# 37                                                4.5
# 38                                                1.4
